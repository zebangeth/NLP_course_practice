# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data
syn_data = pd.read_csv('syn_finetune_loss.csv')
real_data = pd.read_csv('real_finetune_loss.csv')

# %%
syn_data
# Out:
#          Time  Step  Training_Loss
# 0    00:14:43   999         2.6954
# 1    00:14:43   998         2.7960
# 2    00:14:43   997         2.5168
# 3    00:14:43   996         2.8702
# 4    00:14:43   995         2.6252
# ..        ...   ...            ...
# 994  23:56:08     5        10.1568
# 995  23:56:08     4         9.4222
# 996  23:56:05     3        10.2790
# 997  23:56:04     2        10.5386
# 998  23:56:03     1         9.8244
#
# [999 rows x 3 columns]

# %%
# line plot of training loss
plt.figure(figsize=(10, 6))
plt.plot(syn_data['Step'], syn_data['Training_Loss'], label='Synthetic')
plt.plot(real_data['Step'], real_data['Training_Loss'], label='Real')
plt.title('Training Loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.legend()
